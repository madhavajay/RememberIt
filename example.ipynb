# %%
# !uv pip install -e ./

# %%
# !uv pip install -U rememberit

# %%
import rememberit

# %%
# rememberit.login(email="", password="")

# %%
rememberit.help()

# %%
rememberit.sync()

# %%
rememberit.decks()

# %%
rememberit.llmtxt()

# %%
import rememberit

# rememberit.login("email@example.com", "password") # if you haven't logged in yet
decks = rememberit.sync()

# Add or update a deck in bulk
deck_data = {
    "name": "CLI Demo",
    "cards": [
        {"front": "Front 1", "back": "Back 1"},
        {"front": "Front 2", "back": "Back 2"},
    ]
}
rememberit.upsert_deck(deck_data)
